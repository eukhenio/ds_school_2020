# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('houses_to_rent_v2.csv')

# %%
df.head(6)
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
# 5     São Paulo   376      3         3               7     -      acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
# 5  not furnished         0              8000                834
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# 3                   17        1421
# 4                   11         836
# 5                  121        8955

# %%
x = {'acept':True, 'not acept':False}
df['animal'] = df['animal'].map(x)

# %%
df.head(6)
# Out:
#            city  area  rooms  bathroom  parking spaces floor  animal  \
# 0     São Paulo    70      2         1               1     7    True
# 1     São Paulo   320      4         4               0    20    True
# 2  Porto Alegre    80      1         1               1     6    True
# 3  Porto Alegre    51      2         1               0     2    True
# 4     São Paulo    25      1         1               0     1   False
# 5     São Paulo   376      3         3               7     -    True
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
# 5  not furnished         0              8000                834
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# 3                   17        1421
# 4                   11         836
# 5                  121        8955

# %%
y = {'furnished':True, 'not furnished':False}
df['furniture'] = df['furniture'].map(y)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city                 10692 non-null  object
#  1   area                 10692 non-null  int64
#  2   rooms                10692 non-null  int64
#  3   bathroom             10692 non-null  int64
#  4   parking spaces       10692 non-null  int64
#  5   floor                10692 non-null  object
#  6   animal               10692 non-null  bool
#  7   furniture            10692 non-null  bool
#  8   hoa (R$)             10692 non-null  int64
#  9   rent amount (R$)     10692 non-null  int64
#  10  property tax (R$)    10692 non-null  int64
#  11  fire insurance (R$)  10692 non-null  int64
#  12  total (R$)           10692 non-null  int64
# dtypes: bool(2), int64(9), object(2)
# memory usage: 856.3+ KB
# None

# %%
print(df.shape)
# Out:
# (10692, 13)

# %%
pd.set_option('precision', 0)

# %%
df.describe()
# Out:
#         area  rooms  bathroom  parking spaces  hoa (R$)  rent amount (R$)  \
# count  10692  10692     10692           10692     1e+04             10692
# mean     149      3         2               2     1e+03              3896
# std      537      1         1               2     2e+04              3409
# min       11      1         1               0     0e+00               450
# 25%       56      2         1               0     2e+02              1530
# 50%       90      2         2               1     6e+02              2661
# 75%      182      3         3               2     1e+03              5000
# max    46335     13        10              12     1e+06             45000
#
#        property tax (R$)  fire insurance (R$)  total (R$)
# count              10692                10692       1e+04
# mean                 367                   53       5e+03
# std                 3108                   48       2e+04
# min                    0                    3       5e+02
# 25%                   38                   21       2e+03
# 50%                  125                   36       4e+03
# 75%                  375                   68       7e+03
# max               313700                  677       1e+06

# %%
df.describe(include='object')
# Out:
#              city  floor
# count       10692  10692
# unique          5     35
# top     São Paulo      -
# freq         5887   2461

# %%
df['animal'].value_counts()
# Out:
# True     8316
# False    2376
# Name: animal, dtype: int64

# %%
df['furniture'].value_counts()
# Out:
# False    8086
# True     2606
# Name: furniture, dtype: int64

# %%
df.sort_values(by=['rooms'], ascending = False)
# Out:
#                 city  area  rooms  bathroom  parking spaces floor  animal  \
# 7835  Rio de Janeiro   439     13         4               3     -    True
# 5178       São Paulo   400     10         9               8     -    True
# 1639       São Paulo   400     10         5               8     -    True
# 752   Belo Horizonte   341     10         6               7     -    True
# 9565       São Paulo   400      9         4               4     -    True
# ...              ...   ...    ...       ...             ...   ...     ...
# 7246       São Paulo    49      1         1               1    18   False
# 2864       São Paulo    35      1         1               1     7    True
# 8806  Rio de Janeiro    55      1         2               1    15    True
# 5247       São Paulo    23      1         1               1    12    True
# 9208       São Paulo    43      1         1               0     6   False
#
#       furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 7835      False         0             15000                667
# 5178      False         0              8330                550
# 1639      False         0             10900               1417
# 752       False         0              5500                459
# 9565      False       100             12000                500
# ...         ...       ...               ...                ...
# 7246       True       600              5400                  0
# 2864      False       430              2100                  0
# 8806       True       695              2750                 50
# 5247       True       600              2800                 99
# 9208      False       350              1080                 57
#
#       fire insurance (R$)  total (R$)
# 7835                  229       15900
# 5178                  126        9006
# 1639                  164       12480
# 752                    91        6050
# 9565                  181       12780
# ...                   ...         ...
# 7246                   69        6069
# 2864                   27        2557
# 8806                   36        3531
# 5247                   36        3535
# 9208                   14        1501
#
# [10692 rows x 13 columns]

# %%
df.sort_values(by=['bathroom'], ascending=False)
# Out:
#                  city  area  rooms  bathroom  parking spaces floor  animal  \
# 2055        São Paulo   998      7        10               4     -    True
# 9021   Belo Horizonte   458      8        10               4     -    True
# 8187        São Paulo   700      4        10               0     -    True
# 1130        São Paulo   360      4         9               8     -    True
# 5178        São Paulo   400     10         9               8     -    True
# ...               ...   ...    ...       ...             ...   ...     ...
# 5079   Belo Horizonte    92      2         1               0     -    True
# 5075        São Paulo    30      1         1               1     9    True
# 5072        São Paulo    39      1         1               1    24   False
# 5071   Belo Horizonte    66      2         1               1    13    True
# 10691       São Paulo    80      2         1               0     -    True
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 2055        True         0             15000               5000
# 9021       False         0              7000                419
# 8187       False         0             15000               8750
# 1130       False         0              8540               1329
# 5178       False         0              8330                550
# ...          ...       ...               ...                ...
# 5079       False         0              1200                 60
# 5075       False         1              1930                  0
# 5072        True       600              4200                125
# 5071       False       385               550                 26
# 10691      False         0              1400                165
#
#        fire insurance (R$)  total (R$)
# 2055                   226       20230
# 9021                   115        7534
# 8187                   226       23980
# 1130                   129        9998
# 5178                   126        9006
# ...                    ...         ...
# 5079                    20        1280
# 5075                    25        1956
# 5072                    54        4979
# 5071                     8         969
# 10691                   22        1587
#
# [10692 rows x 13 columns]

# %%
df.sort_values(by=['rent amount (R$)'], ascending=False)
# Out:
#                  city  area  rooms  bathroom  parking spaces floor  animal  \
# 2182        São Paulo   700      4         7               8     -    True
# 7748        São Paulo   350      3         3               3     -    True
# 6947        São Paulo   486      8         4               6     -    True
# 2619        São Paulo    80      2         1               1     1    True
# 1743        São Paulo   410      4         5               5     1    True
# ...               ...   ...    ...       ...             ...   ...     ...
# 8070         Campinas    30      1         1               0    15    True
# 7502     Porto Alegre    40      1         1               0     1    True
# 5152        São Paulo    35      1         1               0     -   False
# 4022   Belo Horizonte    31      1         1               1     3   False
# 10627  Belo Horizonte    22      1         1               0     -    True
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 2182       False         0             45000               8750
# 7748       False         0             30000                560
# 6947       False         0             25000               2200
# 2619       False       875             24000                  0
# 1743       False         0             20000                  0
# ...          ...       ...               ...                ...
# 8070       False       280               500                 10
# 7502       False       328               500                140
# 5152       False         0               500                  0
# 4022       False       550               460                 92
# 10627      False        30               450                 13
#
#        fire insurance (R$)  total (R$)
# 2182                   677       54430
# 7748                   451       31010
# 6947                   376       27580
# 2619                   305       25180
# 1743                   254       20250
# ...                    ...         ...
# 8070                     7         797
# 7502                     8         976
# 5152                     8         508
# 4022                     7        1109
# 10627                    6         499
#
# [10692 rows x 13 columns]

# %%
df.sort_values(by=['area'], ascending=False)
# Out:
#                 city   area  rooms  bathroom  parking spaces floor  animal  \
# 2397  Belo Horizonte  46335      4         8               5    11    True
# 5915       São Paulo  24606      5         4               4    12    True
# 9241        Campinas  12732      3         2               0     3    True
# 8790  Belo Horizonte   2000      3         3               2     2    True
# 5129  Belo Horizonte   2000      4         2               3     -    True
# ...              ...    ...    ...       ...             ...   ...     ...
# 6695       São Paulo     15      1         1               0     -   False
# 1588       São Paulo     13      1         1               0     2    True
# 4864       São Paulo     13      1         1               0     1    True
# 6784       São Paulo     12      1         1               0     -   False
# 785        São Paulo     11      1         1               0     1   False
#
#       furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 2397       True       960              8500                646
# 5915      False      2254              8100               7859
# 9241      False       700              1600                 96
# 8790       True      3000              5000                200
# 5129      False         0              4956                200
# ...         ...       ...               ...                ...
# 6695       True         0              1200                 83
# 1588      False         0              2200                 42
# 4864      False         0              2200                  5
# 6784      False         0               950                 50
# 785        True       300              2000                 42
#
#       fire insurance (R$)  total (R$)
# 2397                  114       10220
# 5915                  103       18320
# 9241                   21        2417
# 8790                   67        8267
# 5129                   82        5238
# ...                   ...         ...
# 6695                   16        1299
# 1588                   28        2270
# 4864                   28        2233
# 6784                   13        1013
# 785                    26        2368
#
# [10692 rows x 13 columns]

# %%
df['city'].unique()
# Out:
# array(['São Paulo', 'Porto Alegre', 'Rio de Janeiro', 'Campinas',
#        'Belo Horizonte'], dtype=object)

# %%
df.loc[df['city'] == 'São Paulo'].mean()
# Out:
# area                   2e+02
# rooms                  3e+00
# bathroom               2e+00
# parking spaces         2e+00
# animal                 8e-01
# furniture              3e-01
# hoa (R$)               1e+03
# rent amount (R$)       5e+03
# property tax (R$)      5e+02
# fire insurance (R$)    6e+01
# total (R$)             6e+03
# dtype: float64

# %%
df.loc[df['city'] == 'Porto Alegre'].mean()
# Out:
# area                   1e+02
# rooms                  2e+00
# bathroom               2e+00
# parking spaces         1e+00
# animal                 8e-01
# furniture              3e-01
# hoa (R$)               5e+02
# rent amount (R$)       2e+03
# property tax (R$)      1e+02
# fire insurance (R$)    4e+01
# total (R$)             3e+03
# dtype: float64

# %%
df.loc[df['city'] == 'Rio de Janeiro'].mean()
# Out:
# area                   1e+02
# rooms                  2e+00
# bathroom               2e+00
# parking spaces         7e-01
# animal                 8e-01
# furniture              3e-01
# hoa (R$)               1e+03
# rent amount (R$)       3e+03
# property tax (R$)      3e+02
# fire insurance (R$)    4e+01
# total (R$)             5e+03
# dtype: float64

# %%
df.loc[df['city'] == 'Campinas'].mean()
# Out:
# area                   1e+02
# rooms                  2e+00
# bathroom               2e+00
# parking spaces         2e+00
# animal                 8e-01
# furniture              1e-01
# hoa (R$)               6e+02
# rent amount (R$)       2e+03
# property tax (R$)      1e+02
# fire insurance (R$)    3e+01
# total (R$)             3e+03
# dtype: float64

# %%
df.loc[df['city'] == 'Belo Horizonte'].mean()
# Out:
# area                   2e+02
# rooms                  3e+00
# bathroom               2e+00
# parking spaces         2e+00
# animal                 7e-01
# furniture              1e-01
# hoa (R$)               2e+03
# rent amount (R$)       4e+03
# property tax (R$)      3e+02
# fire insurance (R$)    5e+01
# total (R$)             6e+03
# dtype: float64

# %%
# Belo Horizonte and sao paulo have the biggest averege areas. They are also the most expensive cities in the list
#Porto Alegre and Campinas are the cheapest cities

# %%
plt.rcParams['figure.figsize'] = (8, 6)

# %%
pd.crosstab(df['total (R$)'], df['furniture'], margins=False)
# Out:
# furniture   False  True
# total (R$)
# 499             1      0
# 507             2      0
# 508             1      0
# 509             1      0
# 545             1      0
# ...           ...    ...
# 95610           0      1
# 222100          0      1
# 233200          1      0
# 316900          1      0
# 1120000         2      0
#
# [5751 rows x 2 columns]

# %%
df['non-insurance price'] = df['rent amount (R$)'] + df['property tax (R$)']
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor  animal  \
# 0     São Paulo    70      2         1               1     7    True
# 1     São Paulo   320      4         4               0    20    True
# 2  Porto Alegre    80      1         1               1     6    True
# 3  Porto Alegre    51      2         1               0     2    True
# 4     São Paulo    25      1         1               0     1   False
#
#    furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0       True      2065              3300                211
# 1      False      1200              4960               1750
# 2      False      1000              2800                  0
# 3      False       270              1112                 22
# 4      False         0               800                 25
#
#    fire insurance (R$)  total (R$)  no_insurance_price  non-insurance price
# 0                   42        5618                3511                 3511
# 1                   63        7973                6710                 6710
# 2                   41        3841                2800                 2800
# 3                   17        1421                1134                 1134
# 4                   11         836                 825                  825

# %%
sns.countplot(x='city', hue='animal', data=df.head(10));
plt.savefig('total_and_furniture.png', dpi=300);

# %%
sns.countplot(x='city', hue='furniture', data=df.head(10));
plt.savefig('total_and_furniture.png', dpi=300);

# %%
sns.countplot(x='city', hue='parking spaces', data=df.head(100));
plt.savefig('total_and_furniture.png', dpi=300);

# %%
sns.countplot(x='city', hue='rent amount (R$)', data=df);
plt.savefig('total_and_furniture.png', dpi=300);

# %%
sns.countplot(x='total (R$)', hue='city', data=df.head(10));
plt.savefig('total_and_furniture.png', dpi=300);

# %%
sns.countplot(x='city', hue='rent amount (R$)', data=df.head(100));
plt.savefig('total_and_furniture.png', dpi=300);

# %%
sns.countplot(x='city', hue='floor', data=df.head(100));
plt.savefig('total_and_furniture.png', dpi=300);

# %%
sns.countplot(x='city', hue='property tax (R$)', data=df.head(100));
plt.savefig('total_and_furniture.png', dpi=300);

# %%
sns.countplot(x='city', hue='non-insurance price', data=df.head(100));
plt.savefig('total_and_furniture.png', dpi=300);

# %%
#according to the analysis  I can say tha Sao Paolo is the most comfortable city for renting a house. 
#It has a wide range of prices and conditions.
#If you have animals, it is not a problem to take them with you. Most of houses will allow you to have a pet.
#If you live closer to the clouds, Sao Paolo and Rio de Janeiro are cities for you.
#the only disadvantage of this sity is that you highly likely will have too spend some money for furniture.
