# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtemAvanesov/Roonyx-Labs/blob/master/AvanesovArtem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.metrics import classification_report
from tensorflow.random import set_seed
import random
from keras import layers
from keras.layers import Dropout
from keras import models
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from scipy import ndimage
import pandas as pd
import shutil
import cv2
import os

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read and unzip data

# %%
base_dir = '/content/drive/My Drive/Colab/Roonyx/work_5'
zip_path = base_dir + '/leaf_diseases.zip'
unzip_path = base_dir + '/dataset'

# !mkdir '$unzip_path'
# !unzip -d '$unzip_path' '$zip_path'

# %% [markdown]
# # Examples of input data

# %%
leafs = pd.read_csv(unzip_path+'/plant-pathology-2020-fgvc7/train.csv') 
y = np.array(leafs.drop(["image_id"], axis=1).values)

example_images = []
labels_example_images = []

for i in range(0,10,1):
  img = cv2.imread("/content/drive/My Drive/Colab/Roonyx/work_5/dataset/plant-pathology-2020-fgvc7/images/Train_{}.jpg".format(i))
  example_images.append(img)
  if y[i][0]==1: 
    labels_example_images.append("healthy")
  elif y[i][1]==1: 
    labels_example_images.append("multiple_diseases")
  elif y[i][2]==1: 
    labels_example_images.append("rust")
  elif y[i][3]==1: 
    labels_example_images.append("scab")

fix,axes = plt.subplots(2,5, figsize=(20,8), subplot_kw={'xticks':(),'yticks':()})
for name, image, ax in zip(labels_example_images, example_images, axes.ravel()):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    ax.imshow(image, cmap=plt.cm.binary)
    ax.set_title(name)

# %% [markdown]
# # Plotting class distribution histogram

# %%
num_healthy = sum(y[:,0])
num_multiple_diseases = sum(y[:,1])
num_rust = sum(y[:,2])
num_scab = sum(y[:,3])

plt.hist([1]*num_healthy,bins=4, label = "healthy", width = 0.7)
plt.hist([2]*num_multiple_diseases,bins=4, label = "multiple_diseases", width = 0.7)
plt.hist([3]*num_rust,bins=4, label = "rust", width = 0.7)
plt.hist([4]*num_scab,bins=4, label = "scab", width = 0.7)
plt.ylim(0,max(num_healthy,num_multiple_diseases,num_rust, num_scab)*1.4)
plt.xlim(0.7,5)
plt.legend(loc='best')

# %% [markdown]
# There are quite a few samples of class "multiple_diseases" relative to the rest of the classes. It could be a problem to define this class. Let's try to add additional samples based on transformations of existing images.

# %% [markdown]
# # Adding data for second class

# %%
def generate_new_leafs(image):
    
    new_images = []
    new_images.append(cv2.flip(image,0))
    new_images.append(ndimage.rotate(image, 90))
    new_images.append(cv2.flip(image,1))
    new_images.append(ndimage.rotate(image, 180))
    new_images.append(ndimage.rotate(image, 270))
    
    labels = ['vertical reflection', 'rotated 90 degrees', 'horizontal reflection', 'rotated 180 degrees', 'rotated 270 degrees']
    
    return new_images, labels

# %% [markdown]
# ## Example of adding data for second class

# %%
image = cv2.imread("/content/drive/My Drive/Colab/Roonyx/work_5/dataset/plant-pathology-2020-fgvc7/images/Train_338.jpg")
new_images, new_labels = generate_new_leafs(image)

images = [image] + new_images
labels = ['original'] + new_labels

fix,axes = plt.subplots(2,3, figsize=(18,8), subplot_kw={'xticks':(),'yticks':()})
for img, label, ax in zip(images, labels, axes.ravel()):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax.imshow(img, cmap=plt.cm.binary)
    ax.set_title(label)

# %% [markdown]
# ## Adding generated data

# %%
max_id = len(y)
cur_id = max_id

f = open(unzip_path + "/plant-pathology-2020-fgvc7/train.csv", 'a')

for i in range(0,max_id,1):
  if y[i][1] == 1:
    image = cv2.imread(unzip_path+ "/plant-pathology-2020-fgvc7/images/Train_{}.jpg".format(i))
    images,_ = generate_new_leafs(image)
    for img in images:
      cv2.imwrite(unzip_path+ "/plant-pathology-2020-fgvc7/images/Train_{}.jpg".format(cur_id), img)
      f.write("Train_{},0,1,0,0\n".format(cur_id))
      y = np.append(y,[[0,1,0,0]], 0)
      cur_id += 1

f.close()

# %% [markdown]
# # Plotting class distribution histogram after adding images

# %%
num_healthy = sum(y[:,0])
num_multiple_diseases = sum(y[:,1])
num_rust = sum(y[:,2])
num_scab = sum(y[:,3])

plt.hist([1]*num_healthy,bins=4, label = "healthy", width = 0.7)
plt.hist([2]*num_multiple_diseases,bins=4, label = "multiple_diseases", width = 0.7)
plt.hist([3]*num_rust,bins=4, label = "rust", width = 0.7)
plt.hist([4]*num_scab,bins=4, label = "scab", width = 0.7)
plt.ylim(0,max(num_healthy,num_multiple_diseases,num_rust, num_scab)*1.4)
plt.xlim(0.7,5)
plt.legend(loc='best')

# %% [markdown]
# # Splitting data

# %% [markdown]
# ## Creating directories for train, test, validation

# %%
splitted_dataset_path = base_dir + '/splitted_dataset'
os.mkdir(splitted_dataset_path)

train_dir = os.path.join(splitted_dataset_path, 'train')
os.mkdir(train_dir)
validation_dir = os.path.join(splitted_dataset_path, 'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(splitted_dataset_path, 'test')
os.mkdir(test_dir)

for path in [train_dir, test_dir, validation_dir]:
  for num_class in [0,1,2,3]:
    class_dir = os.path.join(path, str(num_class) + '_class')
    os.mkdir(class_dir)

# %% [markdown]
# ## Search image indexes for each class

# %%
indices_class_0, indices_class_1, indices_class_2, indices_class_3 = [], [], [], []
for i in range(0, len(y),1):
  if(np.argmax(y[i]) == 0):
    indices_class_0.append(i)
  elif(np.argmax(y[i]) == 1):
    indices_class_1.append(i)
  elif(np.argmax(y[i]) == 2):
    indices_class_2.append(i)
  elif(np.argmax(y[i]) == 3):
    indices_class_3.append(i)

# %% [markdown]
# ## Shuffling Index Arrays

# %%
seed = 42
np.random.seed(seed)
set_seed(seed)

random.shuffle(indices_class_0)
random.shuffle(indices_class_1)
random.shuffle(indices_class_2)
random.shuffle(indices_class_3)

indices_classes = [indices_class_0, indices_class_1, indices_class_2, indices_class_3]

# %% [markdown]
# ## Calculation num of elements in test, train and validation samples

# %%
percent_validation = 15
percent_test = 15

num_test = []
num_validation = []
num_train = []
for i in range(0,4,1):
  num_test.append(int(len(indices_classes[i])*percent_test/100))
  num_validation.append(int(len(indices_classes[i])*percent_validation/100))
  num_train.append(len(indices_classes[i])-num_test[-1] - num_validation[-1])

array_for_pandas = np.transpose([num_train, num_validation, num_test])

df = pd.DataFrame({
     '': ['Train', 'Validation', 'Test'],
     'Class 0': array_for_pandas[0,:],
     'Class 1': array_for_pandas[1,:],
     'Class 2': array_for_pandas[2,:],
     'Class 3': array_for_pandas[3,:]
 })

df
# Out:
#                Class 0  Class 1  Class 2  Class 3
# 0       Train      362      384      436      416
# 1  Validation       77       81       93       88
# 2        Test       77       81       93       88

# %% [markdown]
# ## Writing data with train, test and validation samples

# %%
src = unzip_path + '/plant-pathology-2020-fgvc7/images'

# For test images
for num_class in [0,1,2,3]:
  test_fnames = ['Train_{}.jpg'.format(i) for i in indices_classes[num_class][0:num_test[num_class]]]
  for fname in test_fnames:
    shutil.copyfile(src+'/'+fname, test_dir+'/'+str(num_class)+'_class'+'/'+fname)

# For validation images 
for num_class in [0,1,2,3]:
  validation_fnames = ['Train_{}.jpg'.format(i) for i in indices_classes[num_class][num_test[num_class]:num_test[num_class] + num_validation[num_class]]]
  for fname in validation_fnames:
    shutil.copyfile(src+'/'+fname, validation_dir+'/'+str(num_class)+'_class'+'/'+fname)

# For train images
for num_class in [0,1,2,3]:
  train_fnames = ['Train_{}.jpg'.format(i) for i in indices_classes[num_class][num_test[num_class] + num_validation[num_class]:]]
  for fname in train_fnames:
    shutil.copyfile(src+'/'+fname, train_dir+'/'+str(num_class)+'_class'+'/'+fname)

# %% [markdown]
# # Preprocessing data

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=100,
        class_mode='categorical')

validation_generator = validation_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=100,
        class_mode='categorical')

test_generator=test_datagen.flow_from_directory(
        test_dir,
        target_size=(150,150),
        batch_size=100,
        class_mode='categorical')
# Out:
# Found 1598 images belonging to 4 classes.
# Found 339 images belonging to 4 classes.
# Found 339 images belonging to 4 classes.

# %% [markdown]
# # Model of Convolutional Neural Network

# %%
def my_net(dropout=False , dropout_value = 0.0):

  model = models.Sequential()

  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  if dropout:
    model.add(Dropout(dropout_value))

  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  if dropout:
    model.add(Dropout(dropout_value))

  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  if dropout:
    model.add(Dropout(dropout_value))

  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  if dropout:
    model.add(Dropout(dropout_value))

  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  if dropout:
    model.add(Dropout(dropout_value))

  model.add(layers.Dense(512, activation='relu'))
  model.add(layers.Dense(4, activation='softmax'))

  return model

# %% [markdown]
# # Neural network without dropout

# %%
model = my_net()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 15, 15, 128)       73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 128)         147584
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1638912
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,918,724
# Trainable params: 1,918,724
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Neural network training

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(
              train_generator,
              steps_per_epoch=sum(num_train)//100,
              epochs=30,
              validation_data=validation_generator,
              validation_steps=sum(num_validation)//100)
# Out:
# Epoch 1/30
# 15/15 [==============================] - 66s 4s/step - loss: 1.4008 - accuracy: 0.2684 - val_loss: 1.3770 - val_accuracy: 0.2733
# Epoch 2/30
# 15/15 [==============================] - 67s 4s/step - loss: 1.3717 - accuracy: 0.2724 - val_loss: 1.4086 - val_accuracy: 0.2971
# Epoch 3/30
# 15/15 [==============================] - 58s 4s/step - loss: 1.3547 - accuracy: 0.3244 - val_loss: 1.3179 - val_accuracy: 0.3305
# Epoch 4/30
# 15/15 [==============================] - 58s 4s/step - loss: 1.3227 - accuracy: 0.3685 - val_loss: 1.3679 - val_accuracy: 0.3891
# Epoch 5/30
# 15/15 [==============================] - 64s 4s/step - loss: 1.2205 - accuracy: 0.4640 - val_loss: 1.2968 - val_accuracy: 0.4500
# Epoch 6/30
# 15/15 [==============================] - 68s 5s/step - loss: 1.1059 - accuracy: 0.5080 - val_loss: 0.9489 - val_accuracy: 0.5858
# Epoch 7/30
# 15/15 [==============================] - 58s 4s/step - loss: 1.0362 - accuracy: 0.5513 - val_loss: 0.9176 - val_accuracy: 0.5607
# Epoch 8/30
# 15/15 [==============================] - 58s 4s/step - loss: 0.9208 - accuracy: 0.5975 - val_loss: 0.9056 - val_accuracy: 0.6192
# Epoch 9/30
# 15/15 [==============================] - 65s 4s/step - loss: 0.8657 - accuracy: 0.6348 - val_loss: 0.8084 - val_accuracy: 0.6667
# Epoch 10/30
# 15/15 [==============================] - 68s 5s/step - loss: 0.7100 - accuracy: 0.7049 - val_loss: 0.8297 - val_accuracy: 0.6820
# Epoch 11/30
# 15/15 [==============================] - 58s 4s/step - loss: 0.6693 - accuracy: 0.7263 - val_loss: 0.7118 - val_accuracy: 0.7155
# Epoch 12/30
# 15/15 [==============================] - 57s 4s/step - loss: 0.5880 - accuracy: 0.7503 - val_loss: 0.7419 - val_accuracy: 0.6820
# Epoch 13/30
# 15/15 [==============================] - 64s 4s/step - loss: 0.5183 - accuracy: 0.7861 - val_loss: 0.8483 - val_accuracy: 0.6800
# Epoch 14/30
# 15/15 [==============================] - 67s 4s/step - loss: 0.4573 - accuracy: 0.8111 - val_loss: 0.5672 - val_accuracy: 0.7238
# Epoch 15/30
# 15/15 [==============================] - 58s 4s/step - loss: 0.4592 - accuracy: 0.8160 - val_loss: 0.6823 - val_accuracy: 0.6862
# Epoch 16/30
# 15/15 [==============================] - 57s 4s/step - loss: 0.3672 - accuracy: 0.8545 - val_loss: 0.7454 - val_accuracy: 0.7155
# Epoch 17/30
# 15/15 [==============================] - 63s 4s/step - loss: 0.2748 - accuracy: 0.8919 - val_loss: 0.6840 - val_accuracy: 0.7333
# Epoch 18/30
# 15/15 [==============================] - 67s 4s/step - loss: 0.2334 - accuracy: 0.9132 - val_loss: 0.8621 - val_accuracy: 0.7490
# Epoch 19/30
# 15/15 [==============================] - 58s 4s/step - loss: 0.2296 - accuracy: 0.9112 - val_loss: 1.1401 - val_accuracy: 0.6402
# Epoch 20/30
# 15/15 [==============================] - 57s 4s/step - loss: 0.2073 - accuracy: 0.9253 - val_loss: 0.9897 - val_accuracy: 0.6778
# Epoch 21/30
# 15/15 [==============================] - 64s 4s/step - loss: 0.1457 - accuracy: 0.9505 - val_loss: 0.9139 - val_accuracy: 0.7333
# Epoch 22/30
# 15/15 [==============================] - 67s 4s/step - loss: 0.0952 - accuracy: 0.9700 - val_loss: 1.1616 - val_accuracy: 0.7238
# Epoch 23/30
# 15/15 [==============================] - 58s 4s/step - loss: 0.0734 - accuracy: 0.9760 - val_loss: 0.8711 - val_accuracy: 0.7490
# Epoch 24/30
# 15/15 [==============================] - 58s 4s/step - loss: 0.0612 - accuracy: 0.9853 - val_loss: 1.3071 - val_accuracy: 0.6820
# Epoch 25/30
# 15/15 [==============================] - 64s 4s/step - loss: 0.0671 - accuracy: 0.9800 - val_loss: 1.2595 - val_accuracy: 0.7067
# Epoch 26/30
# 15/15 [==============================] - 67s 4s/step - loss: 0.0468 - accuracy: 0.9880 - val_loss: 0.9955 - val_accuracy: 0.7029
# Epoch 27/30
# 15/15 [==============================] - 57s 4s/step - loss: 0.0222 - accuracy: 0.9947 - val_loss: 1.4405 - val_accuracy: 0.7573
# Epoch 28/30
# 15/15 [==============================] - 57s 4s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.0155 - val_accuracy: 0.7197
# Epoch 29/30
# 15/15 [==============================] - 63s 4s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.0056 - val_accuracy: 0.7233
# Epoch 30/30
# 15/15 [==============================] - 66s 4s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.7570 - val_accuracy: 0.7071

# %%
model.save(base_dir+'/model_without_dropout.h5')

# %% [markdown]
# ## Accuracy and loss

# %%
plt.figure(figsize=(10,3))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# %% [markdown]
# ## Metrics

# %%
preds = np.array([])
y_true = np.array([])

for _ in range(len(test_generator)):
  images, labels = test_generator.next()
  pred = model.predict(images)
  preds = np.concatenate((preds, np.argmax(pred, axis=1)))
  y_true = np.concatenate((y_true, np.argmax(labels, axis=1)))

print(classification_report(y_true, preds, target_names=['healthy', 'multiple_diseases', 'rust', 'scab']))
# Out:
#                    precision    recall  f1-score   support
#
#           healthy       0.73      0.86      0.79        77
# multiple_diseases       0.68      0.67      0.68        81
#              rust       0.87      0.84      0.85        93
#              scab       0.73      0.66      0.69        88
#
#          accuracy                           0.76       339
#         macro avg       0.75      0.76      0.75       339
#      weighted avg       0.76      0.76      0.75       339

# %% [markdown]
# # Neural network with dropout

# %%
model_array = []
dropout_array = [0.1, 0.2, 0.3, 0.5]
for dropout_value in dropout_array:
  model_array.append(my_net(dropout=True, dropout_value=dropout_value))

model_array[0].summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_56 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 15, 15, 128)       73856
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 5, 5, 128)         147584
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 3200)              0
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 3200)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 512)               1638912
# _________________________________________________________________
# dense_24 (Dense)             (None, 4)                 2052
# =================================================================
# Total params: 1,918,724
# Trainable params: 1,918,724
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Neural network training

# %%
history_array = []
for model_nn in model_array:
  model_nn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  history_array.append(model_nn.fit(
                train_generator,
                steps_per_epoch=sum(num_train)//100,
                epochs=40,
                validation_data=validation_generator,
                validation_steps=sum(num_validation)//100))
  print("\n")
# Out:
# Epoch 1/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.3897 - accuracy: 0.2477 - val_loss: 1.3820 - val_accuracy: 0.2800
# Epoch 2/40
# 15/15 [==============================] - 68s 5s/step - loss: 1.3820 - accuracy: 0.2810 - val_loss: 1.3679 - val_accuracy: 0.2720
# Epoch 3/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.3777 - accuracy: 0.2844 - val_loss: 1.3754 - val_accuracy: 0.2845
# Epoch 4/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.3532 - accuracy: 0.3247 - val_loss: 1.3468 - val_accuracy: 0.2594
# Epoch 5/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.3508 - accuracy: 0.3117 - val_loss: 1.3178 - val_accuracy: 0.3500
# Epoch 6/40
# 15/15 [==============================] - 67s 4s/step - loss: 1.3348 - accuracy: 0.3311 - val_loss: 1.3414 - val_accuracy: 0.3891
# Epoch 7/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.3126 - accuracy: 0.3563 - val_loss: 1.3235 - val_accuracy: 0.4017
# Epoch 8/40
# 15/15 [==============================] - 59s 4s/step - loss: 1.3024 - accuracy: 0.3507 - val_loss: 1.3093 - val_accuracy: 0.4100
# Epoch 9/40
# 15/15 [==============================] - 66s 4s/step - loss: 1.3112 - accuracy: 0.3678 - val_loss: 1.3351 - val_accuracy: 0.3400
# Epoch 10/40
# 15/15 [==============================] - 69s 5s/step - loss: 1.2995 - accuracy: 0.3638 - val_loss: 1.2480 - val_accuracy: 0.3473
# Epoch 11/40
# 15/15 [==============================] - 59s 4s/step - loss: 1.2474 - accuracy: 0.4045 - val_loss: 1.2863 - val_accuracy: 0.3724
# Epoch 12/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.2104 - accuracy: 0.4298 - val_loss: 1.1969 - val_accuracy: 0.5146
# Epoch 13/40
# 15/15 [==============================] - 66s 4s/step - loss: 1.1439 - accuracy: 0.4773 - val_loss: 1.0665 - val_accuracy: 0.4800
# Epoch 14/40
# 15/15 [==============================] - 69s 5s/step - loss: 1.0652 - accuracy: 0.5227 - val_loss: 1.0130 - val_accuracy: 0.5565
# Epoch 15/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.9665 - accuracy: 0.5808 - val_loss: 0.8323 - val_accuracy: 0.6109
# Epoch 16/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.8632 - accuracy: 0.6415 - val_loss: 0.7922 - val_accuracy: 0.6192
# Epoch 17/40
# 15/15 [==============================] - 64s 4s/step - loss: 0.7416 - accuracy: 0.6789 - val_loss: 0.7965 - val_accuracy: 0.6267
# Epoch 18/40
# 15/15 [==============================] - 68s 5s/step - loss: 0.6031 - accuracy: 0.7497 - val_loss: 0.8607 - val_accuracy: 0.6862
# Epoch 19/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.5120 - accuracy: 0.7944 - val_loss: 1.0315 - val_accuracy: 0.5941
# Epoch 20/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.4644 - accuracy: 0.8084 - val_loss: 0.8723 - val_accuracy: 0.6904
# Epoch 21/40
# 15/15 [==============================] - 63s 4s/step - loss: 0.3840 - accuracy: 0.8471 - val_loss: 0.9932 - val_accuracy: 0.6533
# Epoch 22/40
# 15/15 [==============================] - 68s 5s/step - loss: 0.3545 - accuracy: 0.8652 - val_loss: 1.0498 - val_accuracy: 0.6192
# Epoch 23/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.3175 - accuracy: 0.8625 - val_loss: 0.8169 - val_accuracy: 0.6695
# Epoch 24/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.2141 - accuracy: 0.9280 - val_loss: 0.7704 - val_accuracy: 0.6695
# Epoch 25/40
# 15/15 [==============================] - 65s 4s/step - loss: 0.1762 - accuracy: 0.9338 - val_loss: 1.1547 - val_accuracy: 0.6867
# Epoch 26/40
# 15/15 [==============================] - 69s 5s/step - loss: 0.1551 - accuracy: 0.9379 - val_loss: 1.1820 - val_accuracy: 0.6820
# Epoch 27/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.1356 - accuracy: 0.9560 - val_loss: 1.0076 - val_accuracy: 0.6569
# Epoch 28/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.1462 - accuracy: 0.9499 - val_loss: 2.0140 - val_accuracy: 0.6904
# Epoch 29/40
# 15/15 [==============================] - 65s 4s/step - loss: 0.1101 - accuracy: 0.9606 - val_loss: 1.2005 - val_accuracy: 0.7033
# Epoch 30/40
# 15/15 [==============================] - 68s 5s/step - loss: 0.0830 - accuracy: 0.9720 - val_loss: 1.5660 - val_accuracy: 0.6736
# Epoch 31/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.0510 - accuracy: 0.9853 - val_loss: 1.7833 - val_accuracy: 0.6653
# Epoch 32/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.0509 - accuracy: 0.9833 - val_loss: 2.6287 - val_accuracy: 0.7280
# Epoch 33/40
# 15/15 [==============================] - 65s 4s/step - loss: 0.0763 - accuracy: 0.9733 - val_loss: 2.0218 - val_accuracy: 0.6667
# Epoch 34/40
# 15/15 [==============================] - 69s 5s/step - loss: 0.0872 - accuracy: 0.9700 - val_loss: 1.7347 - val_accuracy: 0.6778
# Epoch 35/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.0577 - accuracy: 0.9826 - val_loss: 1.3952 - val_accuracy: 0.7238
# Epoch 36/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.0520 - accuracy: 0.9840 - val_loss: 2.8034 - val_accuracy: 0.6485
# Epoch 37/40
# 15/15 [==============================] - 65s 4s/step - loss: 0.0379 - accuracy: 0.9880 - val_loss: 1.8900 - val_accuracy: 0.6733
# Epoch 38/40
# 15/15 [==============================] - 69s 5s/step - loss: 0.0306 - accuracy: 0.9920 - val_loss: 1.3674 - val_accuracy: 0.6862
# Epoch 39/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.0272 - accuracy: 0.9900 - val_loss: 1.6106 - val_accuracy: 0.6569
# Epoch 40/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.0198 - accuracy: 0.9960 - val_loss: 2.0320 - val_accuracy: 0.6569
#
#
# Epoch 1/40
# 15/15 [==============================] - 67s 4s/step - loss: 1.4034 - accuracy: 0.2563 - val_loss: 1.3835 - val_accuracy: 0.2567
# Epoch 2/40
# 15/15 [==============================] - 68s 5s/step - loss: 1.3853 - accuracy: 0.2650 - val_loss: 1.3880 - val_accuracy: 0.2510
# Epoch 3/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.3849 - accuracy: 0.2550 - val_loss: 1.3802 - val_accuracy: 0.2887
# Epoch 4/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.3854 - accuracy: 0.2590 - val_loss: 1.3870 - val_accuracy: 0.2720
# Epoch 5/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.3790 - accuracy: 0.2767 - val_loss: 1.3574 - val_accuracy: 0.2700
# Epoch 6/40
# 15/15 [==============================] - 67s 4s/step - loss: 1.3774 - accuracy: 0.2877 - val_loss: 1.3568 - val_accuracy: 0.3515
# Epoch 7/40
# 15/15 [==============================] - 57s 4s/step - loss: 1.3544 - accuracy: 0.3382 - val_loss: 1.3466 - val_accuracy: 0.3724
# Epoch 8/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.3624 - accuracy: 0.3151 - val_loss: 1.3637 - val_accuracy: 0.3431
# Epoch 9/40
# 15/15 [==============================] - 65s 4s/step - loss: 1.3551 - accuracy: 0.3291 - val_loss: 1.3102 - val_accuracy: 0.3967
# Epoch 10/40
# 15/15 [==============================] - 68s 5s/step - loss: 1.3361 - accuracy: 0.3633 - val_loss: 1.3065 - val_accuracy: 0.3598
# Epoch 11/40
# 15/15 [==============================] - 57s 4s/step - loss: 1.3052 - accuracy: 0.3710 - val_loss: 1.3224 - val_accuracy: 0.3891
# Epoch 12/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.2783 - accuracy: 0.3939 - val_loss: 1.2623 - val_accuracy: 0.4393
# Epoch 13/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.2707 - accuracy: 0.4180 - val_loss: 1.3026 - val_accuracy: 0.3933
# Epoch 14/40
# 15/15 [==============================] - 68s 5s/step - loss: 1.2356 - accuracy: 0.4339 - val_loss: 1.2572 - val_accuracy: 0.3975
# Epoch 15/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.2209 - accuracy: 0.4533 - val_loss: 1.2698 - val_accuracy: 0.3808
# Epoch 16/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.1897 - accuracy: 0.4706 - val_loss: 1.2834 - val_accuracy: 0.4435
# Epoch 17/40
# 15/15 [==============================] - 65s 4s/step - loss: 1.1534 - accuracy: 0.4833 - val_loss: 1.2363 - val_accuracy: 0.4233
# Epoch 18/40
# 15/15 [==============================] - 68s 5s/step - loss: 1.0894 - accuracy: 0.5240 - val_loss: 1.3164 - val_accuracy: 0.3849
# Epoch 19/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.0461 - accuracy: 0.5387 - val_loss: 1.2656 - val_accuracy: 0.3808
# Epoch 20/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.9899 - accuracy: 0.5816 - val_loss: 1.2664 - val_accuracy: 0.4100
# Epoch 21/40
# 15/15 [==============================] - 64s 4s/step - loss: 0.9410 - accuracy: 0.5988 - val_loss: 1.3631 - val_accuracy: 0.3933
# Epoch 22/40
# 15/15 [==============================] - 67s 4s/step - loss: 0.8825 - accuracy: 0.6155 - val_loss: 1.3490 - val_accuracy: 0.4226
# Epoch 23/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.7658 - accuracy: 0.6953 - val_loss: 1.5981 - val_accuracy: 0.4059
# Epoch 24/40
# 15/15 [==============================] - 60s 4s/step - loss: 0.7433 - accuracy: 0.6936 - val_loss: 1.3731 - val_accuracy: 0.4226
# Epoch 25/40
# 15/15 [==============================] - 65s 4s/step - loss: 0.6399 - accuracy: 0.7467 - val_loss: 1.8559 - val_accuracy: 0.3833
# Epoch 26/40
# 15/15 [==============================] - 68s 5s/step - loss: 0.5417 - accuracy: 0.7853 - val_loss: 1.4570 - val_accuracy: 0.3640
# Epoch 27/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.4589 - accuracy: 0.8191 - val_loss: 1.8750 - val_accuracy: 0.3640
# Epoch 28/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.3735 - accuracy: 0.8511 - val_loss: 2.3498 - val_accuracy: 0.3933
# Epoch 29/40
# 15/15 [==============================] - 65s 4s/step - loss: 0.3462 - accuracy: 0.8678 - val_loss: 1.9994 - val_accuracy: 0.3967
# Epoch 30/40
# 15/15 [==============================] - 68s 5s/step - loss: 0.3061 - accuracy: 0.8838 - val_loss: 2.1047 - val_accuracy: 0.3598
# Epoch 31/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.2903 - accuracy: 0.8965 - val_loss: 1.8702 - val_accuracy: 0.3556
# Epoch 32/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.2650 - accuracy: 0.9025 - val_loss: 2.4501 - val_accuracy: 0.3808
# Epoch 33/40
# 15/15 [==============================] - 66s 4s/step - loss: 0.2052 - accuracy: 0.9292 - val_loss: 2.0120 - val_accuracy: 0.3767
# Epoch 34/40
# 15/15 [==============================] - 69s 5s/step - loss: 0.1606 - accuracy: 0.9399 - val_loss: 2.9128 - val_accuracy: 0.3891
# Epoch 35/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.1830 - accuracy: 0.9366 - val_loss: 2.9807 - val_accuracy: 0.3598
# Epoch 36/40
# 15/15 [==============================] - 59s 4s/step - loss: 0.1351 - accuracy: 0.9539 - val_loss: 2.9113 - val_accuracy: 0.4226
# Epoch 37/40
# 15/15 [==============================] - 65s 4s/step - loss: 0.1334 - accuracy: 0.9559 - val_loss: 2.7892 - val_accuracy: 0.4067
# Epoch 38/40
# 15/15 [==============================] - 69s 5s/step - loss: 0.1085 - accuracy: 0.9647 - val_loss: 4.1722 - val_accuracy: 0.3556
# Epoch 39/40
# 15/15 [==============================] - 58s 4s/step - loss: 0.1299 - accuracy: 0.9545 - val_loss: 2.8797 - val_accuracy: 0.4184
# Epoch 40/40
# 15/15 [==============================] - 57s 4s/step - loss: 0.2270 - accuracy: 0.9272 - val_loss: 2.7418 - val_accuracy: 0.3515
#
#
# Epoch 1/40
# 15/15 [==============================] - 68s 5s/step - loss: 1.4321 - accuracy: 0.2510 - val_loss: 1.3838 - val_accuracy: 0.2567
# Epoch 2/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.3859 - accuracy: 0.2617 - val_loss: 1.3849 - val_accuracy: 0.2720
# Epoch 3/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.3834 - accuracy: 0.2650 - val_loss: 1.3863 - val_accuracy: 0.2762
# Epoch 4/40
# 15/15 [==============================] - 53s 4s/step - loss: 1.3816 - accuracy: 0.2613 - val_loss: 1.3808 - val_accuracy: 0.2594
# Epoch 5/40
# 15/15 [==============================] - 58s 4s/step - loss: 1.3766 - accuracy: 0.2981 - val_loss: 1.3763 - val_accuracy: 0.2867
# Epoch 6/40
# 15/15 [==============================] - 61s 4s/step - loss: 1.3665 - accuracy: 0.3127 - val_loss: 1.3314 - val_accuracy: 0.3431
# Epoch 7/40
# 15/15 [==============================] - 52s 3s/step - loss: 1.3595 - accuracy: 0.3117 - val_loss: 1.3914 - val_accuracy: 0.2301
# Epoch 8/40
# 15/15 [==============================] - 53s 4s/step - loss: 1.3568 - accuracy: 0.3111 - val_loss: 1.3154 - val_accuracy: 0.3640
# Epoch 9/40
# 15/15 [==============================] - 60s 4s/step - loss: 1.3526 - accuracy: 0.3295 - val_loss: 1.3523 - val_accuracy: 0.3200
# Epoch 10/40
# 15/15 [==============================] - 63s 4s/step - loss: 1.3377 - accuracy: 0.3258 - val_loss: 1.3022 - val_accuracy: 0.3891
# Epoch 11/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.3244 - accuracy: 0.3480 - val_loss: 1.2936 - val_accuracy: 0.3347
# Epoch 12/40
# 15/15 [==============================] - 53s 4s/step - loss: 1.3190 - accuracy: 0.3672 - val_loss: 1.3626 - val_accuracy: 0.3682
# Epoch 13/40
# 15/15 [==============================] - 59s 4s/step - loss: 1.3193 - accuracy: 0.3585 - val_loss: 1.3115 - val_accuracy: 0.3733
# Epoch 14/40
# 15/15 [==============================] - 62s 4s/step - loss: 1.3086 - accuracy: 0.3658 - val_loss: 1.2992 - val_accuracy: 0.4017
# Epoch 15/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.3067 - accuracy: 0.3865 - val_loss: 1.3679 - val_accuracy: 0.3515
# Epoch 16/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.3151 - accuracy: 0.3585 - val_loss: 1.3345 - val_accuracy: 0.3975
# Epoch 17/40
# 15/15 [==============================] - 60s 4s/step - loss: 1.2797 - accuracy: 0.3900 - val_loss: 1.2706 - val_accuracy: 0.4033
# Epoch 18/40
# 15/15 [==============================] - 63s 4s/step - loss: 1.2533 - accuracy: 0.4098 - val_loss: 1.3049 - val_accuracy: 0.4017
# Epoch 19/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.2071 - accuracy: 0.4320 - val_loss: 1.2388 - val_accuracy: 0.4310
# Epoch 20/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.1994 - accuracy: 0.4739 - val_loss: 1.2502 - val_accuracy: 0.4100
# Epoch 21/40
# 15/15 [==============================] - 60s 4s/step - loss: 1.1562 - accuracy: 0.4907 - val_loss: 1.1496 - val_accuracy: 0.4167
# Epoch 22/40
# 15/15 [==============================] - 63s 4s/step - loss: 1.1137 - accuracy: 0.5087 - val_loss: 1.0481 - val_accuracy: 0.5774
# Epoch 23/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.0061 - accuracy: 0.5701 - val_loss: 0.9148 - val_accuracy: 0.5816
# Epoch 24/40
# 15/15 [==============================] - 54s 4s/step - loss: 0.9313 - accuracy: 0.6068 - val_loss: 0.8420 - val_accuracy: 0.6025
# Epoch 25/40
# 15/15 [==============================] - 60s 4s/step - loss: 0.8762 - accuracy: 0.6303 - val_loss: 0.8335 - val_accuracy: 0.6300
# Epoch 26/40
# 15/15 [==============================] - 64s 4s/step - loss: 0.8218 - accuracy: 0.6393 - val_loss: 0.7509 - val_accuracy: 0.6736
# Epoch 27/40
# 15/15 [==============================] - 55s 4s/step - loss: 0.7510 - accuracy: 0.6705 - val_loss: 0.7643 - val_accuracy: 0.6151
# Epoch 28/40
# 15/15 [==============================] - 54s 4s/step - loss: 0.6722 - accuracy: 0.7127 - val_loss: 0.9862 - val_accuracy: 0.6653
# Epoch 29/40
# 15/15 [==============================] - 60s 4s/step - loss: 0.6662 - accuracy: 0.7253 - val_loss: 1.0188 - val_accuracy: 0.6600
# Epoch 30/40
# 15/15 [==============================] - 63s 4s/step - loss: 0.6311 - accuracy: 0.7340 - val_loss: 0.9926 - val_accuracy: 0.6904
# Epoch 31/40
# 15/15 [==============================] - 54s 4s/step - loss: 0.5851 - accuracy: 0.7650 - val_loss: 0.7056 - val_accuracy: 0.6611
# Epoch 32/40
# 15/15 [==============================] - 54s 4s/step - loss: 0.5653 - accuracy: 0.7530 - val_loss: 0.7560 - val_accuracy: 0.7113
# Epoch 33/40
# 15/15 [==============================] - 60s 4s/step - loss: 0.5036 - accuracy: 0.7953 - val_loss: 0.6809 - val_accuracy: 0.6967
# Epoch 34/40
# 15/15 [==============================] - 63s 4s/step - loss: 0.4490 - accuracy: 0.8088 - val_loss: 0.6485 - val_accuracy: 0.6946
# Epoch 35/40
# 15/15 [==============================] - 54s 4s/step - loss: 0.4355 - accuracy: 0.8313 - val_loss: 0.5616 - val_accuracy: 0.7280
# Epoch 36/40
# 15/15 [==============================] - 55s 4s/step - loss: 0.4208 - accuracy: 0.8249 - val_loss: 0.9113 - val_accuracy: 0.7238
# Epoch 37/40
# 15/15 [==============================] - 60s 4s/step - loss: 0.3994 - accuracy: 0.8431 - val_loss: 0.7591 - val_accuracy: 0.7500
# Epoch 38/40
# 15/15 [==============================] - 64s 4s/step - loss: 0.3430 - accuracy: 0.8712 - val_loss: 0.7474 - val_accuracy: 0.7197
# Epoch 39/40
# 15/15 [==============================] - 55s 4s/step - loss: 0.3279 - accuracy: 0.8752 - val_loss: 0.8136 - val_accuracy: 0.6820
# Epoch 40/40
# 15/15 [==============================] - 55s 4s/step - loss: 0.4196 - accuracy: 0.8420 - val_loss: 0.9168 - val_accuracy: 0.6695
#
#
# Epoch 1/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.4623 - accuracy: 0.2543 - val_loss: 1.3843 - val_accuracy: 0.2333
# Epoch 2/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.3844 - accuracy: 0.2590 - val_loss: 1.3813 - val_accuracy: 0.2929
# Epoch 3/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.3831 - accuracy: 0.2907 - val_loss: 1.3866 - val_accuracy: 0.2385
# Epoch 4/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.3852 - accuracy: 0.2694 - val_loss: 1.3823 - val_accuracy: 0.2803
# Epoch 5/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.3809 - accuracy: 0.2613 - val_loss: 1.3831 - val_accuracy: 0.2700
# Epoch 6/40
# 15/15 [==============================] - 66s 4s/step - loss: 1.3845 - accuracy: 0.2844 - val_loss: 1.3832 - val_accuracy: 0.2803
# Epoch 7/40
# 15/15 [==============================] - 56s 4s/step - loss: 1.3813 - accuracy: 0.2540 - val_loss: 1.3835 - val_accuracy: 0.2803
# Epoch 8/40
# 15/15 [==============================] - 55s 4s/step - loss: 1.3768 - accuracy: 0.2724 - val_loss: 1.3670 - val_accuracy: 0.2678
# Epoch 9/40
# 15/15 [==============================] - 61s 4s/step - loss: 1.3695 - accuracy: 0.3193 - val_loss: 1.3684 - val_accuracy: 0.4033
# Epoch 10/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.3583 - accuracy: 0.3275 - val_loss: 1.3650 - val_accuracy: 0.4017
# Epoch 11/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.3706 - accuracy: 0.2927 - val_loss: 1.3799 - val_accuracy: 0.4226
# Epoch 12/40
# 15/15 [==============================] - 55s 4s/step - loss: 1.3602 - accuracy: 0.3224 - val_loss: 1.3756 - val_accuracy: 0.3849
# Epoch 13/40
# 15/15 [==============================] - 60s 4s/step - loss: 1.3333 - accuracy: 0.3485 - val_loss: 1.3474 - val_accuracy: 0.2600
# Epoch 14/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.3138 - accuracy: 0.3692 - val_loss: 1.3034 - val_accuracy: 0.4435
# Epoch 15/40
# 15/15 [==============================] - 55s 4s/step - loss: 1.2785 - accuracy: 0.4032 - val_loss: 1.3342 - val_accuracy: 0.4226
# Epoch 16/40
# 15/15 [==============================] - 54s 4s/step - loss: 1.2869 - accuracy: 0.3925 - val_loss: 1.2875 - val_accuracy: 0.4603
# Epoch 17/40
# 15/15 [==============================] - 61s 4s/step - loss: 1.2776 - accuracy: 0.4000 - val_loss: 1.2902 - val_accuracy: 0.4467
# Epoch 18/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.2487 - accuracy: 0.4124 - val_loss: 1.2880 - val_accuracy: 0.4393
# Epoch 19/40
# 15/15 [==============================] - 56s 4s/step - loss: 1.2222 - accuracy: 0.4440 - val_loss: 1.1891 - val_accuracy: 0.5314
# Epoch 20/40
# 15/15 [==============================] - 55s 4s/step - loss: 1.1745 - accuracy: 0.4886 - val_loss: 1.1489 - val_accuracy: 0.5146
# Epoch 21/40
# 15/15 [==============================] - 61s 4s/step - loss: 1.1540 - accuracy: 0.4786 - val_loss: 1.0886 - val_accuracy: 0.5233
# Epoch 22/40
# 15/15 [==============================] - 64s 4s/step - loss: 1.1052 - accuracy: 0.5254 - val_loss: 0.9484 - val_accuracy: 0.6318
# Epoch 23/40
# 15/15 [==============================] - 55s 4s/step - loss: 1.0347 - accuracy: 0.5720 - val_loss: 0.9283 - val_accuracy: 0.5858
# Epoch 24/40
# 15/15 [==============================] - 55s 4s/step - loss: 1.0501 - accuracy: 0.5448 - val_loss: 0.8839 - val_accuracy: 0.5649
# Epoch 25/40
# 15/15 [==============================] - 62s 4s/step - loss: 0.9456 - accuracy: 0.6028 - val_loss: 0.9111 - val_accuracy: 0.6233
# Epoch 26/40
# 15/15 [==============================] - 65s 4s/step - loss: 0.9588 - accuracy: 0.5900 - val_loss: 0.9337 - val_accuracy: 0.6109
# Epoch 27/40
# 15/15 [==============================] - 55s 4s/step - loss: 0.9203 - accuracy: 0.6128 - val_loss: 0.7876 - val_accuracy: 0.6318
# Epoch 28/40
# 15/15 [==============================] - 55s 4s/step - loss: 0.8717 - accuracy: 0.6409 - val_loss: 1.0071 - val_accuracy: 0.5858
# Epoch 29/40
# 15/15 [==============================] - 60s 4s/step - loss: 0.8498 - accuracy: 0.6364 - val_loss: 0.8065 - val_accuracy: 0.6100
# Epoch 30/40
# 15/15 [==============================] - 65s 4s/step - loss: 0.7963 - accuracy: 0.6607 - val_loss: 0.8036 - val_accuracy: 0.6862
# Epoch 31/40
# 15/15 [==============================] - 56s 4s/step - loss: 0.7816 - accuracy: 0.6629 - val_loss: 0.8181 - val_accuracy: 0.6151
# Epoch 32/40
# 15/15 [==============================] - 55s 4s/step - loss: 0.7832 - accuracy: 0.6615 - val_loss: 0.9526 - val_accuracy: 0.6820
# Epoch 33/40
# 15/15 [==============================] - 62s 4s/step - loss: 0.7611 - accuracy: 0.6816 - val_loss: 0.8064 - val_accuracy: 0.6800
# Epoch 34/40
# 15/15 [==============================] - 65s 4s/step - loss: 0.7571 - accuracy: 0.6742 - val_loss: 0.7493 - val_accuracy: 0.6276
# Epoch 35/40
# 15/15 [==============================] - 55s 4s/step - loss: 0.7194 - accuracy: 0.6956 - val_loss: 0.6927 - val_accuracy: 0.7071
# Epoch 36/40
# 15/15 [==============================] - 54s 4s/step - loss: 0.7339 - accuracy: 0.6889 - val_loss: 0.9660 - val_accuracy: 0.6402
# Epoch 37/40
# 15/15 [==============================] - 60s 4s/step - loss: 0.6808 - accuracy: 0.7167 - val_loss: 0.7599 - val_accuracy: 0.6967
# Epoch 38/40
# 15/15 [==============================] - 64s 4s/step - loss: 0.6291 - accuracy: 0.7390 - val_loss: 0.7431 - val_accuracy: 0.7029
# Epoch 39/40
# 15/15 [==============================] - 55s 4s/step - loss: 0.6142 - accuracy: 0.7380 - val_loss: 0.7344 - val_accuracy: 0.6904
# Epoch 40/40
# 15/15 [==============================] - 54s 4s/step - loss: 0.5872 - accuracy: 0.7530 - val_loss: 0.7655 - val_accuracy: 0.7238

# %% [markdown]
# ## Accuracy and loss

# %%
for i in range (0,len(history_array),1):

  plt.figure(figsize=(10,3))

  plt.subplot(1, 2, 1)
  plt.plot(history_array[i].history['accuracy'])
  plt.plot(history_array[i].history['val_accuracy'])
  plt.title('Model accuracy (dropout = {})'.format(dropout_array[i]))
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.ylim(0,1.1)
  plt.legend(['Train', 'Test'], loc='upper left')

  plt.subplot(1, 2, 2)
  plt.plot(history_array[i].history['loss'])
  plt.plot(history_array[i].history['val_loss'])
  plt.title('Model loss (dropout = {})'.format(dropout_array[i]))
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.ylim(0,2.5)
  plt.legend(['Train', 'Test'], loc='upper left')

# %% [markdown]
# # Some more epochs for model with dropout = 0.5

# %%
more_history = model_array[3].fit(
                   train_generator,
                   steps_per_epoch=sum(num_train)//100,
                   epochs=20,
                   validation_data=validation_generator,
                   validation_steps=sum(num_validation)//100)
# Out:
# Epoch 1/20
# 15/15 [==============================] - 60s 4s/step - loss: 0.6152 - accuracy: 0.7517 - val_loss: 0.6653 - val_accuracy: 0.7100
# Epoch 2/20
# 15/15 [==============================] - 64s 4s/step - loss: 0.6073 - accuracy: 0.7323 - val_loss: 0.5582 - val_accuracy: 0.7406
# Epoch 3/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.5766 - accuracy: 0.7460 - val_loss: 0.5805 - val_accuracy: 0.7699
# Epoch 4/20
# 15/15 [==============================] - 54s 4s/step - loss: 0.5720 - accuracy: 0.7600 - val_loss: 0.6532 - val_accuracy: 0.6778
# Epoch 5/20
# 15/15 [==============================] - 60s 4s/step - loss: 0.5872 - accuracy: 0.7620 - val_loss: 0.7154 - val_accuracy: 0.7233
# Epoch 6/20
# 15/15 [==============================] - 64s 4s/step - loss: 0.5724 - accuracy: 0.7520 - val_loss: 0.6611 - val_accuracy: 0.7406
# Epoch 7/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.5146 - accuracy: 0.7991 - val_loss: 0.6275 - val_accuracy: 0.7699
# Epoch 8/20
# 15/15 [==============================] - 54s 4s/step - loss: 0.5370 - accuracy: 0.7757 - val_loss: 0.7973 - val_accuracy: 0.6402
# Epoch 9/20
# 15/15 [==============================] - 61s 4s/step - loss: 0.5667 - accuracy: 0.7567 - val_loss: 0.6337 - val_accuracy: 0.7600
# Epoch 10/20
# 15/15 [==============================] - 64s 4s/step - loss: 0.5084 - accuracy: 0.7881 - val_loss: 0.7067 - val_accuracy: 0.6736
# Epoch 11/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.5439 - accuracy: 0.7667 - val_loss: 0.7380 - val_accuracy: 0.6862
# Epoch 12/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.5070 - accuracy: 0.8031 - val_loss: 0.7169 - val_accuracy: 0.7573
# Epoch 13/20
# 15/15 [==============================] - 62s 4s/step - loss: 0.4761 - accuracy: 0.8117 - val_loss: 0.5459 - val_accuracy: 0.7367
# Epoch 14/20
# 15/15 [==============================] - 66s 4s/step - loss: 0.4628 - accuracy: 0.8144 - val_loss: 0.5802 - val_accuracy: 0.7615
# Epoch 15/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.4351 - accuracy: 0.8318 - val_loss: 0.7453 - val_accuracy: 0.7155
# Epoch 16/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.4411 - accuracy: 0.8244 - val_loss: 0.4461 - val_accuracy: 0.7699
# Epoch 17/20
# 15/15 [==============================] - 62s 4s/step - loss: 0.4265 - accuracy: 0.8231 - val_loss: 0.8373 - val_accuracy: 0.7567
# Epoch 18/20
# 15/15 [==============================] - 64s 4s/step - loss: 0.4008 - accuracy: 0.8433 - val_loss: 0.5847 - val_accuracy: 0.7657
# Epoch 19/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.3609 - accuracy: 0.8576 - val_loss: 0.7041 - val_accuracy: 0.7364
# Epoch 20/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.4086 - accuracy: 0.8458 - val_loss: 0.4670 - val_accuracy: 0.7406

# %% [markdown]
# ## Accuracy and loss model with dropout = 0.5 after adding 20 epochs

# %%
plt.figure(figsize=(10,3))

plt.subplot(1, 2, 1)
plt.plot(more_history.history['accuracy'])
plt.plot(more_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(more_history.history['loss'])
plt.plot(more_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# %% [markdown]
# # Metrics on the best model

# %%
index_best_model = 3
best_model = model_array[index_best_model]

preds = np.array([])
y_true = np.array([])

for _ in range(len(test_generator)):
  images, labels = test_generator.next()
  pred = best_model.predict(images)
  preds = np.concatenate((preds, np.argmax(pred, axis=1)))
  y_true = np.concatenate((y_true, np.argmax(labels, axis=1)))

print(classification_report(y_true, preds, target_names=['healthy', 'multiple_diseases', 'rust', 'scab']))
# Out:
#                    precision    recall  f1-score   support
#
#           healthy       0.74      0.79      0.77        77
# multiple_diseases       0.68      0.37      0.48        81
#              rust       0.78      0.83      0.80        93
#              scab       0.65      0.84      0.73        88
#
#          accuracy                           0.71       339
#         macro avg       0.71      0.71      0.70       339
#      weighted avg       0.71      0.71      0.70       339

# %% [markdown]
# # Feature maps of the best model

# %%
imgs,labels = train_generator.next()
img = imgs[:1]

num_in_row = 8

names = []
outputs = []

for layer in best_model.layers:
  if 'conv' in layer.name:
    outputs.append(layer.output)
    names.append(layer.name)

model2 = Model(inputs = best_model.inputs, outputs=outputs)

feature_maps = model2.predict(img)
for feature_maps, l_name in zip(feature_maps, names):
  fmap = np.transpose(feature_maps[0], axes = [2,1,0])
  fig, axes = plt.subplots(int(len(fmap)/num_in_row), num_in_row, figsize = (16, 2*int(len(fmap)/num_in_row)), subplot_kw={'xticks':(), 'yticks':()})
  fig.suptitle(l_name, fontsize = 40)

  for image, ax in zip(fmap, axes.ravel()):
    ax.imshow(image)

# %%
for i in range(0, len(dropout_array),1):
  model_array[i].save(base_dir+"/model_with_dropout_{}.h5".format(str(dropout_array[i])))

# %% [markdown]
# # Result accuracy models

# %%
_, accuracy_dropout = best_model.evaluate(test_generator)
_, accuracy_without_dropout = model.evaluate(test_generator)
print("\nAccuracy the best model without dropout: {:.3f}".format(accuracy_without_dropout))
print("Accuracy the best model with dropout: {:.3f}".format(accuracy_dropout))
# Out:
# 4/4 [==============================] - 12s 3s/step
# 4/4 [==============================] - 12s 3s/step
#
# Accuracy the best model without dropout: 0.714
# Accuracy the best model with dropout: 0.755

# %% [markdown]
# # Conclusions

# %% [markdown]
# - Model without dropout is overfitting.
# - Model with dropout is less overfitting so it has better results.
# - Low value of dropout doesn't give a positive result.
# - The best model is model with dropout=0.5 and it has 75.5% accuracy on test data.
